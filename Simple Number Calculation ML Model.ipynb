# %% [markdown]
# ### Simple Number Calculation Machine Learning Program
# ##### Hi! This here is a simple machine learning program
# ##### Referenced from Ridwan Ilyas' youtube video about the basics of Machine Learning.

# %%
#Import libraries
import keras
import numpy as np

# %% [markdown]
# ##### Start the modeling process

# %%
num_model = keras.Sequential([keras.layers.Dense(units=1, input_shape = [1])])

# %% [markdown]
# #### The compiling process and the Training process
# ##### Here we compile a few things.
# ##### This is based on a simple function where [data*3] + 4
# ##### Where we compile xs is the input, and ys is the output
# ##### The Mean Squared Error measures how close a regression line is to a set of data points. It is a risk function corresponding to the expected value of the squared error loss.

# %%
num_model.compile(optimizer = 'sgd', loss='MSE')
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0],dtype=float)
ys = np.array([1.0, 4.0, 7.0, 10.0, 13.0, 16.0], dtype=float)
num_model.fit(xs, ys, epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 565ms/step - loss: 140.4087
# Epoch 2/200
# 1/1 [==============================] - 0s 6ms/step - loss: 111.1472
# Epoch 3/200
# 1/1 [==============================] - 0s 8ms/step - loss: 88.1117
# Epoch 4/200
# 1/1 [==============================] - 0s 7ms/step - loss: 69.9748
# Epoch 5/200
# 1/1 [==============================] - 0s 8ms/step - loss: 55.6922
# Epoch 6/200
# 1/1 [==============================] - 0s 7ms/step - loss: 44.4421
# Epoch 7/200
# 1/1 [==============================] - 0s 7ms/step - loss: 35.5783
# Epoch 8/200
# 1/1 [==============================] - 0s 7ms/step - loss: 28.5920
# Epoch 9/200
# 1/1 [==============================] - 0s 7ms/step - loss: 23.0832
# Epoch 10/200
# 1/1 [==============================] - 0s 7ms/step - loss: 18.7371
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 15.3060
# Epoch 12/200
# ...

# %% [markdown]
# ##### Here, we've trained the model for a total of 500 epochs, and with each epoch, the model gets more accurate and the error decreases
# ##### The Testing Phase

# %%
data = 5.0
answer =num_model.predict([data])
print(answer)
# Out:
# 1/1 [==============================] - 0s 131ms/step
# [[19.19141]]
